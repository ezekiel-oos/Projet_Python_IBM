# %%
# Question 1: Importer les librairies
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Question 2: Télécharger les données de GameStop
gme_data = yf.download('GME', start='2019-01-01', end='2021-01-01')

# Question 3: Réinitialiser l'index et afficher les 5 premières lignes
gme_data.reset_index(inplace=True)
print(gme_data.head())

# %%
import requests
from bs4 import BeautifulSoup

url_tesla = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
html_data = requests.get(url_tesla).text
soup = BeautifulSoup(html_data, "html.parser")

# Extraire le tableau des revenus
tesla_revenue = pd.DataFrame(columns=["Date", "Revenue"])
for row in soup.find_all("tr"):
    cols = row.find_all("td")
    if len(cols) == 2:
        date = cols[0].text.strip()
        revenue = cols[1].text.strip().replace("$","").replace(",","")
        tesla_revenue = pd.concat([tesla_revenue, pd.DataFrame([[date, revenue]], columns=["Date","Revenue"])], ignore_index=True)

tesla_revenue.head()

# %%
import requests
from bs4 import BeautifulSoup

# Extraire les données de revenus de GameStop depuis Macrotrends
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")

# Trouver le tableau des revenus
tables = soup.find_all("table")
gme_revenue = pd.DataFrame(columns=["Date", "Revenue"])

for table in tables:
    rows = table.find_all("tr")
    for row in rows:
        cols = row.find_all("td")
        if len(cols) == 2:
            date = cols[0].text.strip()
            revenue = cols[1].text.strip()
            gme_revenue = pd.concat([gme_revenue, pd.DataFrame({"Date":[date], "Revenue":[revenue]})], ignore_index=True)

# Afficher les 5 dernières lignes
print(gme_revenue.tail())

# %%
# Télécharger les données Tesla
tesla_data = yf.download('TSLA', start='2019-01-01', end='2021-01-01')
tesla_data.reset_index(inplace=True)

# Fonction pour tracer un graphique
def make_graph(data, title):
    plt.figure(figsize=(10,6))
    plt.plot(data['Date'], data['Close'])
    plt.title(title)
    plt.xlabel("Date")
    plt.ylabel("Close Price USD")
    plt.grid(True)
    plt.show()

# Tracer le graphique Tesla
make_graph(tesla_data, "Tesla Stock Price (2019-2021)")

# %%
# Utiliser les données GME déjà téléchargées
make_graph(gme_data, "GameStop Stock Price (2019-2021)")

# %%
# Utiliser les données GME déjà téléchargées
make_graph(gme_data, "GameStop Stock Price (2019-2021)")
